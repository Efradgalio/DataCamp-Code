# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/titanic/gender_submission.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/train.csv

# %% [markdown]
# ### Refresher on Pandas basics
# ```python
# hiking = pd.read_csv('datasets/hiking.json')
# print(hiking.head())```
#
# Preprocessing is like prerequisite

# %% [markdown]
# # Chapter 1

# %% [markdown]
# ### Dealing with missing data
# ```python
# df.isnull().sum()
# df.notnull().sum()
# # Subset the df dataset
# df_subset = df[df['category_desc'].notnull()]
# ```

# %% [markdown]
# ### Working with data types
# ```python
# print(df.dtypes)```
#
# - object: string/mixed types
# - int64: integer
# - float64: float
# - datetime64(or timedelta): datetime

# %% [markdown]
# ### Converting column types
# ```python
# df['C'] = df['C'].astype('float')```
#
# ### Class distribution
# #### Stratified Sampling
# - 100 samples, 80 class 1 and 20 class 2
# - Training set: 75 samples, 60 class 1 and 15 class 2
# - Test set: 25 samples, 20 class 1 and 5 class 2
#
# ```python
# y = y['labels']
#
# X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y)
# y_train['labels'].value_counts()```

# %% [markdown]
# # Chapter 2

# %% [markdown]
# ### Standardizing data
# 1. Scikit-learn models assume normally distributed data if it isn't risk bias your model.
# 2. Applied to continuous numerical data
#
# ### When to standardize: models
# 1. Model in linear space
# 2. Dataset features have high variance can bias the model. If a feature has high variance it could impact model's ability to learn from other features
# 3. Dataset features are continuous and on different scales
# 4. Linearity assumptions

# %% [markdown]
# ### Log normalization
# - Good idea when a feature has a high variance
# - Natural log using the constant e(2.718) --> log 30 is 3.4 , log 300 is 5.7, log 3000 is 8
#
# ```python
# df["log_2"].var()
# df['log_2'] = np.log(df['log_2'])
# ```

# %% [markdown]
# ### Feature scalling
# 1. Features on different scales
# 2. Model with linear characteristics
# 3. Center features around 0 and transform to unit variance
# 4. Transforms to approximately normal distribution

# %% [markdown]
# ```python
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# df_scaled = pd.DataFrame(scaler.fit_transform(df), columns = df.columns)```

# %% [markdown]
# # Chapter 3

# %% [markdown]
# ## Feature engineering
# - Creation of new features based on existing features
# - Insight into relationships between features
# - Extract and expand data
# - Dataset-dependent

# %% [markdown]
# ### Encoding categorical variables
# ```python
# # In pandas
# df['feature_enc'] = df['feature'].apply(lambda val: 1 if val == 'y' else 0)
#
# # Scikit-learn
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# df['feature_enc'] = le.fit_transform(df['feature'])
# ```
#
# ### One hot encoding
# ```python
# df['feature_multi_enc'] = pd.get_dummies(df['feature_multi'])```

# %% [markdown]
# ### Engineering numerical features
# ```python
# columns ['feature_1','feature_2','feature_3']
# df['mean'] = df.apply(lambda row: row[columns].mean(),axis=1)```
#
# ### Dates
# ```python
# df['date_converted'] = pd.to_datetime(df['date']) # Makes the extraction takes much easier
# df['month'] = df['date_converted'].apply(lambda row: row.month)
# ```

# %% [markdown]
# ### Engineering features from text
# - \d --> grab digits and + --> grabs as many as possible
# - \. --> grab the point decimal

# %%
import re
my_string = '75.6 F'
pattern = re.compile('\d+\.\d+') 
temp = re.match(pattern,my_string)
print(float(temp.group(0)))
# Out:
# 75.6

# %% [markdown]
# ### Vectorizing text
# - tf = term frequency
# - idf = inverse document frequency

# %%
train = pd.read_csv('/kaggle/input/titanic/train.csv')
train.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vec = TfidfVectorizer()
text_tfidf = tfidf_vec.fit_transform(train['Name'])
X = text_tfidf.toarray() # In order to get in the proper format for scikit-learn

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
# Split the dataset according to the class distribution of category_desc
y = train.Survived
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y)

nb = GaussianNB()
# Fit the model to the training data
nb.fit(X_train, y_train)

# Print out the model's accuracy
print(nb.score(X_test, y_test))
# Out:
# 0.5112107623318386

# %% [markdown]
# ### Text Classification
# $P(A \ |\ B) = \frac{P(B\ |\ A)\ P(A)}{P(B}$ --> Naive Bayes. It treats each feature as independent from the others, which can be a naive assumption, but this works out well on text data.

# %% [markdown]
# ```python
# # Write a pattern to extract numbers and decimals
# def return_mileage(text):
#     pattern = re.compile(r"\d+\.\d+")
#
#     # Search the text for matches
#     mile = re.match(pattern, text)
#
#     # If a value is returned, use group(0) to return the found value
#     if mile is not None:
#         return float(mile.group(0))
#
# # Apply the function to the text column and take a look at both columns
# df["text_extract"] = df['text'].apply(lambda row: return_mileage(row))
# print(df[["text", "text_extract"]].head())
# ```

# %% [markdown]
# # Chapter 4
# ## Feature Selection
# - Selecting features to be used for modeling
# - Doesn't create new features
# - Improve model's performance

# %% [markdown]
# ### Removing redundant features
# - Redundant features might create noise when modeling
# - Remove noisy features --> Exists in another form as another feature
# - Remove correlated features
# - Remove duplicated features

# %% [markdown]
# ### Scenarios for manual removal
# - City, State, lat, long --> It is Noise ! Choose one depend on your end goal, if it is specific use lat and long, or high-level state information.
# - Extract number from text , you can drop the text feature.
# - Took an average to use as an aggregate statistic, we could drop the values that generated the aggregate statistic.
# - Features that have gone through the feature engineering process are redundant as well.
#
# ### Correlated features
# - Statistically correlated: features move together directionally
# - Linear models assume feature independence
# - Pears correlation coefficient
# ```python
# df.corr()```

# %% [markdown]
# ### Selecting features using text vectors
#
# #### Looking at word weights
# After you've vectorized your text, the vocabulary and weights will be stored in the vectorizer

# %%
print(tfidf_vec.vocabulary_) # From titanic !
# Out:
# {'braund': 177, 'mr': 1012, 'owen': 1096, 'harris': 580, 'cumings': 296, 'mrs': 1013, 'john': 709, 'bradley': 174, 'florence': 458, 'briggs': 183, 'thayer': 1367, 'heikkinen': 599, 'miss': 983, 'laina': 786, 'futrelle': 490, 'jacques': 676, 'heath': 595, 'lily': 835, 'may': 941, 'peel': 1120, 'allen': 46, 'william': 1479, 'henry': 610, 'moran': 1000, 'james': 679, 'mccarthy': 944, 'timothy': 1386, 'palsson': 1099, 'master': 928, 'gosta': 529, 'leonard': 821, 'johnson': 710, 'oscar': 1089, 'elisabeth': 395, 'vilhelmina': 1430, 'berg': 138, 'nasser': 1030, 'nicholas': 1046, 'adele': 12, 'achem': 5, 'sandstrom': 1250, 'marguerite': 905, 'rut': 1232, 'bonnell': 165, 'elizabeth': 398, 'saundercock': 1256, 'andersson': 60, 'anders': 57, 'johan': 701, 'vestrom': 1425, 'hulda': 644, 'amanda': 51, 'adolfina': 16, 'hewlett': 613, 'mary': 925, 'kingcome': 764, 'rice': 1191, 'eugene': 431, 'williams': 1480, 'charles': 235, 'vander': 1419, 'planke': 1160, 'julius': 733, 'emelia': 409, 'maria': 907, 'vandemoortele': 1417, 'masselmani': 927, 'fatima': 446, 'fynney': 491, 'joseph': 721, 'beesley': 132, 'lawrence': 803, 'mcgowan': 951, 'anna': 70, 'annie': 72, 'sloper': 1306, 'thompson': 1375, 'torborg': 1393, 'danira': 313, 'asplund': 88, 'carl': 210, 'selma': 1264, 'augusta': 97, 'emilia': 412, 'johansson': 708, 'emir': 414, 'farred': 443, 'chehab': 239, 'fortune': 467, 'alexander': 33, 'dwyer': 362, 'ellen': 400, 'nellie': 1038, 'todoroff': 1389, 'lalio': 789, 'uruchurtu': 1412, 'don': 345, 'manuel': 896, 'spencer': 1319, 'augustus': 99, 'marie': 909, 'eugenie': 432, 'glynn': 519, 'agatha': 19, 'wheadon': 1468, 'edward': 376, 'meyer': 966, 'edgar': 367, 'holverson': 629, 'oskar': 1091, 'mamee': 886, 'hanna': 564, 'cann': 205, 'ernest': 424, 'nicola': 1049, 'yarred': 1495, 'jamila': 680, 'ahlin': 22, 'johanna': 703, 'persdotter': 1137, 'larsson': 796, 'turpin': 1406, 'robert': 1201, 'dorothy': 350, 'ann': 69, 'wonnacott': 1489, 'kraeff': 775, 'theodor': 1371, 'laroche': 795, 'simonne': 1289, 'anne': 71, 'andree': 64, 'devaney': 334, 'margaret': 899, 'delia': 327, 'rogers': 1207, 'lennon': 818, 'denis': 328, 'driscoll': 358, 'bridget': 180, 'samaan': 1248, 'youssef': 1501, 'arnold': 83, 'franchi': 472, 'josef': 717, 'josefine': 720, 'panula': 1100, 'juha': 726, 'niilo': 1053, 'nosworthy': 1066, 'richard': 1192, 'cater': 221, 'harper': 577, 'sleeper': 1302, 'myna': 1023, 'haxtun': 591, 'faunthorpe': 447, 'lizzie': 846, 'wilkinson': 1477, 'ostby': 1094, 'engelhart': 418, 'cornelius': 284, 'woolner': 1491, 'hugh': 641, 'rugg': 1230, 'emily': 413, 'novel': 1068, 'mansouer': 893, 'west': 1467, 'constance': 277, 'mirium': 982, 'goodwin': 526, 'frederick': 482, 'sirayanian': 1293, 'orsen': 1088, 'icard': 649, 'amelie': 54, 'birkhardt': 155, 'skoog': 1299, 'harald': 570, 'stewart': 1336, 'albert': 28, 'moubarek': 1009, 'gerios': 503, 'nye': 1069, 'ramell': 1177, 'crease': 291, 'erna': 423, 'alexandra': 34, 'kink': 765, 'vincenz': 1434, 'jenkin': 690, 'stephen': 1333, 'curnow': 299, 'lillian': 834, 'amy': 56, 'hood': 632, 'ambrose': 52, 'jr': 725, 'chronopoulos': 250, 'apostolos': 78, 'bing': 152, 'lee': 807, 'moen': 991, 'sigurd': 1281, 'hansen': 569, 'staneff': 1321, 'ivan': 669, 'moutal': 1011, 'rahamin': 1175, 'haim': 553, 'caldwell': 200, 'alden': 32, 'gates': 497, 'dowdell': 352, 'waelens': 1441, 'achille': 6, 'sheerlinck': 1271, 'jan': 681, 'baptist': 113, 'mcdermott': 947, 'brigdet': 182, 'carrau': 216, 'francisco': 474, 'ilett': 655, 'bertha': 145, 'backstrom': 104, 'karl': 743, 'alfred': 39, 'mathilda': 930, 'gustafsson': 549, 'ford': 465, 'neal': 1035, 'slocovski': 1305, 'selman': 1265, 'francis': 473, 'mabel': 869, 'helen': 603, 'celotti': 226, 'francesco': 471, 'christmann': 247, 'emil': 410, 'andreasson': 63, 'paul': 1110, 'edvin': 375, 'chaffee': 228, 'herbert': 611, 'fuller': 488, 'dean': 324, 'bertram': 147, 'frank': 476, 'coxon': 290, 'daniel': 310, 'shorney': 1274, 'goldschmidt': 522, 'george': 500, 'greenfield': 537, 'doling': 342, ...

# %%
print(text_tfidf[3])
# Out:
#   (0, 1120)	0.4248477011002001
#   (0, 941)	0.400586689697735
#   (0, 835)	0.400586689697735
#   (0, 595)	0.400586689697735
#   (0, 676)	0.3833732281680796
#   (0, 490)	0.400586689697735
#   (0, 1013)	0.17507317025147795

# %%
print( text_tfidf[3].data)
# Out:
# [0.4248477  0.40058669 0.40058669 0.40058669 0.38337323 0.40058669
#  0.17507317]

# %%
print( text_tfidf[3].indices)
# Out:
# [1120  941  835  595  676  490 1013]

# %%
vocab = {v:k for k,v in tfidf_vec.vocabulary_.items()} # Swapping the key value pairs
print(vocab)
# Out:
# {177: 'braund', 1012: 'mr', 1096: 'owen', 580: 'harris', 296: 'cumings', 1013: 'mrs', 709: 'john', 174: 'bradley', 458: 'florence', 183: 'briggs', 1367: 'thayer', 599: 'heikkinen', 983: 'miss', 786: 'laina', 490: 'futrelle', 676: 'jacques', 595: 'heath', 835: 'lily', 941: 'may', 1120: 'peel', 46: 'allen', 1479: 'william', 610: 'henry', 1000: 'moran', 679: 'james', 944: 'mccarthy', 1386: 'timothy', 1099: 'palsson', 928: 'master', 529: 'gosta', 821: 'leonard', 710: 'johnson', 1089: 'oscar', 395: 'elisabeth', 1430: 'vilhelmina', 138: 'berg', 1030: 'nasser', 1046: 'nicholas', 12: 'adele', 5: 'achem', 1250: 'sandstrom', 905: 'marguerite', 1232: 'rut', 165: 'bonnell', 398: 'elizabeth', 1256: 'saundercock', 60: 'andersson', 57: 'anders', 701: 'johan', 1425: 'vestrom', 644: 'hulda', 51: 'amanda', 16: 'adolfina', 613: 'hewlett', 925: 'mary', 764: 'kingcome', 1191: 'rice', 431: 'eugene', 1480: 'williams', 235: 'charles', 1419: 'vander', 1160: 'planke', 733: 'julius', 409: 'emelia', 907: 'maria', 1417: 'vandemoortele', 927: 'masselmani', 446: 'fatima', 491: 'fynney', 721: 'joseph', 132: 'beesley', 803: 'lawrence', 951: 'mcgowan', 70: 'anna', 72: 'annie', 1306: 'sloper', 1375: 'thompson', 1393: 'torborg', 313: 'danira', 88: 'asplund', 210: 'carl', 1264: 'selma', 97: 'augusta', 412: 'emilia', 708: 'johansson', 414: 'emir', 443: 'farred', 239: 'chehab', 467: 'fortune', 33: 'alexander', 362: 'dwyer', 400: 'ellen', 1038: 'nellie', 1389: 'todoroff', 789: 'lalio', 1412: 'uruchurtu', 345: 'don', 896: 'manuel', 1319: 'spencer', 99: 'augustus', 909: 'marie', 432: 'eugenie', 519: 'glynn', 19: 'agatha', 1468: 'wheadon', 376: 'edward', 966: 'meyer', 367: 'edgar', 629: 'holverson', 1091: 'oskar', 886: 'mamee', 564: 'hanna', 205: 'cann', 424: 'ernest', 1049: 'nicola', 1495: 'yarred', 680: 'jamila', 22: 'ahlin', 703: 'johanna', 1137: 'persdotter', 796: 'larsson', 1406: 'turpin', 1201: 'robert', 350: 'dorothy', 69: 'ann', 1489: 'wonnacott', 775: 'kraeff', 1371: 'theodor', 795: 'laroche', 1289: 'simonne', 71: 'anne', 64: 'andree', 334: 'devaney', 899: 'margaret', 327: 'delia', 1207: 'rogers', 818: 'lennon', 328: 'denis', 358: 'driscoll', 180: 'bridget', 1248: 'samaan', 1501: 'youssef', 83: 'arnold', 472: 'franchi', 717: 'josef', 720: 'josefine', 1100: 'panula', 726: 'juha', 1053: 'niilo', 1066: 'nosworthy', 1192: 'richard', 221: 'cater', 577: 'harper', 1302: 'sleeper', 1023: 'myna', 591: 'haxtun', 447: 'faunthorpe', 846: 'lizzie', 1477: 'wilkinson', 1094: 'ostby', 418: 'engelhart', 284: 'cornelius', 1491: 'woolner', 641: 'hugh', 1230: 'rugg', 413: 'emily', 1068: 'novel', 893: 'mansouer', 1467: 'west', 277: 'constance', 982: 'mirium', 526: 'goodwin', 482: 'frederick', 1293: 'sirayanian', 1088: 'orsen', 649: 'icard', 54: 'amelie', 155: 'birkhardt', 1299: 'skoog', 570: 'harald', 1336: 'stewart', 28: 'albert', 1009: 'moubarek', 503: 'gerios', 1069: 'nye', 1177: 'ramell', 291: 'crease', 423: 'erna', 34: 'alexandra', 765: 'kink', 1434: 'vincenz', 690: 'jenkin', 1333: 'stephen', 299: 'curnow', 834: 'lillian', 56: 'amy', 632: 'hood', 52: 'ambrose', 725: 'jr', 250: 'chronopoulos', 78: 'apostolos', 152: 'bing', 807: 'lee', 991: 'moen', 1281: 'sigurd', 569: 'hansen', 1321: 'staneff', 669: 'ivan', 1011: 'moutal', 1175: 'rahamin', 553: 'haim', 200: 'caldwell', 32: 'alden', 497: 'gates', 352: 'dowdell', 1441: 'waelens', 6: 'achille', 1271: 'sheerlinck', 681: 'jan', 113: 'baptist', 947: 'mcdermott', 182: 'brigdet', 216: 'carrau', 474: 'francisco', 655: 'ilett', 145: 'bertha', 104: 'backstrom', 743: 'karl', 39: 'alfred', 930: 'mathilda', 549: 'gustafsson', 465: 'ford', 1035: 'neal', 1305: 'slocovski', 1265: 'selman', 473: 'francis', 869: 'mabel', 603: 'helen', 226: 'celotti', 471: 'francesco', 247: 'christmann', 410: 'emil', 63: 'andreasson', 1110: 'paul', 375: 'edvin', 228: 'chaffee', 611: 'herbert', 488: 'fuller', 324: 'dean', 147: 'bertram', 476: 'frank', 290: 'coxon', 310: 'daniel', 1274: 'shorney', 522: 'goldschmidt', 500: 'george', 537: 'greenfield', 342: 'doling', ...

# %%
zipped_row = dict(zip(text_tfidf[3].indices, text_tfidf[3].data))
print(zipped_row)
# Out:
# {1120: 0.4248477011002001, 941: 0.400586689697735, 835: 0.400586689697735, 595: 0.400586689697735, 676: 0.3833732281680796, 490: 0.400586689697735, 1013: 0.17507317025147795}

# %%
def return_weights(vocab,vector,vector_index):
    zipped = dict(zip(vector[vector_index].indices, vector[vector_index].data))
    return {vocab[i]:zipped[i] for i in vector[vector_index].indices}

print(return_weights(vocab,text_tfidf, 3))
# Out:
# {'peel': 0.4248477011002001, 'may': 0.400586689697735, 'lily': 0.400586689697735, 'heath': 0.400586689697735, 'jacques': 0.3833732281680796, 'futrelle': 0.400586689697735, 'mrs': 0.17507317025147795}

# %%
# Add in the rest of the parameters
def return_weights(vocab, original_vocab, vector, vector_index, top_n):
    zipped = dict(zip(vector[vector_index].indices, vector[vector_index].data))
    
    # Let's transform that zipped dict into a series
    zipped_series = pd.Series({vocab[i]:zipped[i] for i in vector[vector_index].indices})
    
    # Let's sort the series to pull out the top n weighted words
    zipped_index = zipped_series.sort_values(ascending=False)[:top_n].index
    return [original_vocab[i] for i in zipped_index]

# Print out the weighted words
print(return_weights(vocab, tfidf_vec.vocabulary_, text_tfidf, 8, 3))
# Out:
# [1430, 138, 1089]

# %%
def words_to_filter(vocab, original_vocab, vector, top_n):
    filter_list = []
    for i in range(0, vector.shape[0]):
    
        # Here we'll call the function from the previous exercise, and extend the list we're creating
        filtered = return_weights(vocab, original_vocab, vector, i, top_n)
        filter_list.extend(filtered)
    # Return the list in a set, so we don't get duplicate word indices
    return set(filter_list)

# Call the function to get the list of word indices
filtered_words = words_to_filter(vocab, tfidf_vec.vocabulary_, text_tfidf, 3)

# By converting filtered_words back to a list, we can use it to filter the columns in the text vector
filtered_text = text_tfidf[:, list(filtered_words)]

# %% [markdown]
# ### Dimensionality reduction
# - Unsupervised learning method
# - Combines/decomposes a feature space
# - Feature extraction - here we'll use to reduce our feature space
#
# ### Principal Componen Analysis
# - Linear transformation to uncorrelated space
# - Captures as much variance as possible in each component

# %%
train.columns
train_num = train[['Pclass','Age','SibSp','Fare','Parch']]

# %%
from sklearn.decomposition import PCA
pca =PCA()
df_pca = pca.fit_transform(train_num.fillna(train_num.Age.median()))

# %% [markdown]
# By default , PCA in scikit-learn keeps the number of components equal to the number of input features

# %%
print(pca.explained_variance_ratio_) # We could drop those components that don't explain much variance
# Out:
# [9.35603583e-01 6.35890026e-02 4.75409826e-04 1.75562765e-04
#  1.56442066e-04]

# %% [markdown]
# ### PCA caveats
# - Difficult to interpret components , more black box method than other methods of dimensionality reduction
# - Do it PCA in end of your prerocessing journey
# - Post processing after PCA are not useful in explaining variance
