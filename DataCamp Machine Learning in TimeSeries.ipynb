aggle/input/heartbeat-sounds/set_b/normal_noisynormal_139_1306519274653_D.wav
# /kaggle/input/heartbeat-sounds/set_b/normal__278_1311163365896_A.wav

# %% [markdown]
# ## What makes a time series?
# 1. An array of numbers that represents the data itself.
# 2. An array that contains a timestamp for each datapoint.

# %%
import pandas as pd 
import maptlotlib.pyplot as plt
data = pd.read_csv('data.csv')
data.head()

# %%
fig,ax = plt.subplot(figsize= (12,6))
data.plot('date','close',ax=ax)
ax.set(title='AAPL daily closing price')

# %% [markdown]
# ### Why machine learning?
# - We can use really big data and really complicated data
# - Predict the future
# - Automate this process
#
# ### Machine learning pipeline
# - Feature extraction
# - Model fitting
# - Prediction and validation

# %%
# Plot the time series in each dataset
fig, axs = plt.subplots(2, 1, figsize=(5, 10))
data.iloc[:1000].plot(x='time', y='data_values', ax=axs[0])
data2.iloc[:1000].plot(x='time', y='data_values', ax=axs[1])
plt.show()

# %% [markdown]
# ### Always visualize your data
# Histograms and scatterplots are a good place to start
# ```python
# # Using matplotlib
# fig,ax = plt.subplots()
# ax.plot(...)
#
# # Using pandas
# fig,ax = plt.subplots()
# df.plot(..., ax=ax)
# ```

# %% [markdown]
# Look at the distribution of your data :
# - Are there any outliers ?
# - Are you missing data ?
# - It is reasonable?

# %%
from sklearn.svm import LinearSVC

# %% [markdown]
# ### Preparing data for scikit-learn
# - scikit-learn expects a particular structure of data: (samples, features)
# - Make sure that your data is at least two-dimensional
# - Make sure that the first dimension is samples

# %% [markdown]
# ### If your data is not shaped properly
# - If the axes are swapped:
# ```python
# array.T.shape```
# - If we're missing an axis, use .reshape():
# ```python
# array.reshape([-1,1]).shape
# ```
#     - -1 will automatically fill that axis with remaining values

# %% [markdown]
# There is one coefficient per input feature
# ```python
# model.coef_```

# %% [markdown]
# ### The heartbeat Acoustic Data
# - Many recordings of heart sounds from different patients
# - Some had normally-functioning hearts, others had abnormalities
# - Data comes in the form of audio files+labels for each file
# - Can we find the 'abnormal' heart beats?

# %%
from glob import glob
files_a = glob('/kaggle/input/heartbeat-sounds/set_a/*.wav')
files_b = glob('/kaggle/input/heartbeat-sounds/set_b/*.wav')

print(files_a)
print(files_b)
# Out:
# ['/kaggle/input/heartbeat-sounds/set_a/normal__201103140132.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222252.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201103200518.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106221254.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201108011117.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201103170121.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201103101140.wav', '/kaggle/input/heartbeat-sounds/set_a/extrahls__201101152255.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201103151912.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201012172012.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201106212102.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201106221418.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106031558.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201101110659.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201105060108.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201103170122.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106101314.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201101051104.wav', '/kaggle/input/heartbeat-sounds/set_a/extrahls__201102070251.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106010559.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201104141251.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201012172010.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201106171155.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__20110501548.wav', '/kaggle/input/heartbeat-sounds/set_a/extrahls__201102071835.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106121445.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106131834.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201103140822.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106030612.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106211041.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201108222234.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201101152256.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222255.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222256.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201108011116.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201103241336.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106061233.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201106061215.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201105190800.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201103291548.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201106040947.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201108011113.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201108011111.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201108222222.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201106211725.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201102270940.wav', '/kaggle/input/heartbeat-sounds/set_a/extrahls__201101070953.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201106040930.wav', '/kaggle/input/heartbeat-sounds/set_a/extrahls__201103170134.wav', '/kaggle/input/heartbeat-sounds/set_a/artifact__201105051017.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222243.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201102201230.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201104241315.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201106130440.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201102260502.wav', '/kaggle/input/heartbeat-sounds/set_a/Aunlabelledtest__201101061552.wav', '/kaggle/input/heartbeat-sounds/set_a/murmur__201108222221.wav', '/kaggle/input/heartbeat-sounds/set_a/normal__201103221214.wav', '/kaggle/inp ...
# ['/kaggle/input/heartbeat-sounds/set_b/normal__140_1306519735121_A.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_164_1307106095995_C1.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__143_1306763822290_C.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__296_1311682952647_A2.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__106_1306776721273_D.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__232_1308748524018_A1.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__177_1307989650056_D.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__156_1306936373241_C.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__200_1308144251434_C.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__174_1307987737137_B.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__173_1307973611151_D.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__154_1306935608852_D.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__196_1308141034858_C.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__150_1306776340746_D.wav', '/kaggle/input/heartbeat-sounds/set_b/extrastole__154_1306935608852_D2.wav', '/kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_167_1307111318050_A1.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__125_1306332456645_B2.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__281_1311165683454_C.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__149_1306776016110_B.wav', '/kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_125_1306332456645_A1.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__123_1306331925797_D.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__158_1306947254705_B2.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__288_1311164615284_B.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__227_1308594233667_D.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_185_1308073325396_D.wav', '/kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_169_1307970398039_A.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__162_1307101835989_A.wav', '/kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_104_1305032492469_A.wav', '/kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_129_1306344506305_A.wav', '/kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_271_1309369876160_A.wav', '/kaggle/input/heartbeat-sounds/set_b/extrastole__128_1306344005749_A.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__237_1308750231222_C1.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__103_1305031931979_C.wav', '/kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_101_1305030823364_E.wav', '/kaggle/input/heartbeat-sounds/set_b/normal_noisynormal_132_1306758754432_B1.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur_noisymurmur_135_1306428972976_B.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__260_1309353164458_A.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__145_1307987561278_C.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__109_1305653972028_B.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__201_1308144942432_B.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__151_1306779785624_D.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__163_1307104470471_B1.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__155_1306935902813_B1.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__148_1306768801551_C.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__141_1306520154450_A.wav', '/kaggle/input/heartbeat-sounds/set_b/murmur__112_1306243000964_A.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__129_1306344506305_D1.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__176_1307988171173_C.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__132_1306758754432_B.wav', '/kaggle/input/heartbeat-sounds/set_b/normal__273_1309370841191_B.wav', '/kaggle/input/heartbeat-sounds/set_b/Bunlabelledtest__213_130824526 ...

# %% [markdown]
# ### Reading in auditory data

# %%
! apt-get install -y libsndfile-dev

# %%
import librosa as lr
# 'load' accepts a path to an audio file
audio, sfreq = lr.load('/kaggle/input/heartbeat-sounds/set_a/normal__201103140132.wav')
print(sfreq)
# Out:
# 22050

# %% [markdown]
# Meaning the sample frequency is 22050, so there are 22050 samples per second

# %% [markdown]
# and the data is stored in audio.

# %% [markdown]
# ### Inferring times from samples
# - Using only the sampling frequency, we can infer the timepoint of each data point in our audio file.
# - Note: this assumes the sampling rate is fixed and no data points are lost

# %% [markdown]
# ### Creating a time array

# %%
# Create an array of indices, one for each sample, and divide by the sampling frequency
indices = np.arange(0, len(audio))
time = indices/ sfreq

# %%
# Find the time stamp for the N-1th data point. Then use linspace() to interpolate from zero to that time
final_time = (len(audio) -1 )/ sfreq
time = np.linspace(0, final_time, sfreq)

# %%
final_time
# Out:
# array([0.00000000e+00, 4.08179720e-04, 8.16359440e-04, ...,
#        8.99913829e+00, 8.99954647e+00, 8.99995465e+00])
